# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import itertools as it
from collections import Counter, defaultdict, deque
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('white')
sns.set_context('notebook', font_scale=1.3)

from agents import Agent
from mouselab_utils import *
from joblib import load, Parallel

# %%
et = ENV_TYPES[0]
sd = 1
result = load(f'data/gp_results/{et}_{sd}.pkl')
pol = load(f'data/policies/{et}_{sd}.pkl')
envs = make_envs(cost=1.00, seed=194, variance_structure=et, n=300)

# %%
util = get_utl(pol, envs, return_mean=False, parallel=Parallel(4))

# %%
sns.distplot(util)
plt.axvline(util.mean(), ls='--', label='test')
plt.axvline(-result.fun, label='train', ls=':', c='r')
plt.legend()
