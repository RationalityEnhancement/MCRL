# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
from agents import Agent
from mouselab import MouselabEnv
from distributions import Normal, Categorical
from policies import FixedPlanPolicy, LiederPolicy
from evaluation import *
from pprint import pprint
import ast
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
trials = pd.read_csv('../experiments/data/human/0.991/trials.csv')

# %%
trials
# Out:
#       Unnamed: 0  pid  info_cost PR_type message  trial_index  trial_i  \
# 0              0    0       1.00    none    none            1      NaN
# 1              1    0       1.00    none    none            2      NaN
# 2              2    0       1.00    none    none            3      NaN
# 3              3    0       1.00    none    none            4      NaN
# 4              4    0       1.00    none    none            5      NaN
# 5              5    0       1.00    none    none            6      NaN
# 6              6    0       1.00    none    none            7      NaN
# 7              7    0       1.00    none    none            8      NaN
# 8              8    0       1.00    none    none            9      NaN
# 9              9    0       1.00    none    none           10      NaN
# 10            10    0       1.00    none    none           11      NaN
# 11            11    0       1.00    none    none           12      NaN
# 12            12    0       1.00    none    none           13      NaN
# 13            13    0       1.00    none    none           14      NaN
# 14            14    0       1.00    none    none           15      NaN
# 15            15    0       1.00    none    none           16      NaN
# 16            16    1       0.25    none    none            1      NaN
# 17            17    1       0.25    none    none            2      NaN
# 18            18    1       0.25    none    none            3      NaN
# 19            19    1       0.25    none    none            4      NaN
# 20            20    1       0.25    none    none            5      NaN
# 21            21    1       0.25    none    none            6      NaN
# 22            22    1       0.25    none    none            7      NaN
# 23            23    1       0.25    none    none            8      NaN
# 24            24    1       0.25    none    none            9      NaN
# 25            25    1       0.25    none    none           10      NaN
# 26            26    1       0.25    none    none           11      NaN
# 27            27    1       0.25    none    none           12      NaN
# 28            28    1       0.25    none    none           13      NaN
# 29            29    1       0.25    none    none           14      NaN
# ...          ...  ...        ...     ...     ...          ...      ...
# 1506        1547  104       4.00    none    none            3      NaN
# 1507        1548  104       4.00    none    none            4      NaN
# 1508        1549  104       4.00    none    none            5      NaN
# 1509        1550  104       4.00    none    none            6      NaN
# 1510        1551  104       4.00    none    none            7      NaN
# 1511        1552  104       4.00    none    none            8      NaN
# 1512        1553  104       4.00    none    none            9      NaN
# 1513        1554  104       4.00    none    none           10      NaN
# 1514        1555  104       4.00    none    none           11      NaN
# 1515        1556  104       4.00    none    none           12      NaN
# 1516        1557  104       4.00    none    none           13      NaN
# 1517        1558  104       4.00    none    none           14      NaN
# 1518        1559  104       4.00    none    none           15      NaN
# 1519        1560  104       4.00    none    none           16      NaN
# 1520        1561  105       1.00    none    none            1      NaN
# 1521        1562  105       1.00    none    none            2      NaN
# 1522        1563  105       1.00    none    none            3      NaN
# 1523        1564  105       1.00    none    none            4      NaN
# 1524        1565  105       1.00    none    none            5      NaN
# 1525        1566  105       1.00    none    none            6      NaN
# 1526        1567  105       1.00    none    none            7      NaN
# 1527        1568  105       1.00    none    none            8      NaN
# 1528        1569  105       1.00    none    none            9      NaN
# 1529        1570  105       1.00    none    none           10      NaN
# 1530        1571  105       1.00    none    none           11      NaN
# 1531        1572  105       1.00    none    none           12      NaN
# 1532        1573  105       1.00    none    none           13      NaN
# 1533        1574  105       1.00    none    none           14      NaN
# 1534        1575  105       1.00    none    none           15      NaN
# 1535        1576  105       1.00    none    none           16      NaN
#
#       delays  score  n_click  \
# 0        [3]  12.00       16
# 1        [3]  26.00        2
# 2        [3]  26.00        2
# 3        [3]  -8.00        4
# 4        [3]  19.00        1
# 5        [3]   4.00        0
# 6        [3]  28.00        0
# 7        [3]  -4.00        0
# 8        [3]   4.00        0
# 9        [3]  -8.00        4
# 10        []  11.00        9
# 11        []  11.00        1
# 12        [] -44.00        0
# 13        []   4.00        0
# 14        []  35.00        1
# 15        []   2.00        2
# 16    [None] -12.00        0
# 17    [None]  27.75        1
# 18    [None]  19.75        1
# 19    [None]  -5.00        4
# 20    [None]  27.75        1
# 21    [None] -20.50        2
# 22    [None]  27.50        2
# 23    [None]  27.75        1
# 24    [None] -21.00        4
# 25    [None]  19.50        2
# 26        []  11.50        2
# 27        []  35.50        2
# 28        []  28.00        0
# 29        []  11.75        1
# ...      ...    ...      ...
# 1506  [None]  -4.00        0
# 1507  [None]  -4.00        0
# 1508  [None] -36.00        0
# 1509  [None]  -4.00        0
# 1510  [None]  28.00        0
# 1511  [None] -28.00        0
# 1512  [None]  12.00        0
# 1513  [None]  28.00        0
# 1514      [] -12.00        0
# 1515      [] -28.00        0
# 1516      [] -12.00        0
# 1517      [] -20.00        0
# 1518      []  -4.00        0
# 1519      []  -4.00        0
# 1520     [3] -20.00       16
# 1521     [3]  18.00        2
# 1522     [3]  -7.00        3
# 1523     [3]  37.00        7
# 1524     [3]  19.00        9
# 1525     [3]  26.00       10
# 1526     [3]  18.00       10
# 1527     [3]  18.00       10
# 1528     [3]  -9.00        5
# 1529     [3]  15.00        5
# 1530      []  32.00        4
# 1531      []  35.00        1
# 1532      []  17.00        3
# 1533      []   0.00        4
# 1534      []  -8.00        4
# 1535      []   0.00        4
#
#                                                  clicks  \
# 0     [5, 6, 7, 8, 9, 10, 12, 11, 1, 2, 3, 4, 13, 14...
# 1                                                [5, 9]
# 2                                                [5, 6]
# 3                                         [5, 13, 9, 1]
# 4                                                   [5]
# 5                                                    []
# 6                                                    []
# 7                                                    []
# 8                                                    []
# 9                                         [5, 9, 13, 1]
# 10                     [9, 10, 12, 11, 13, 5, 6, 14, 2]
# 11                                                  [9]
# 12                                                   []
# 13                                                   []
# 14                                                 [12]
# 15                                               [7, 8]
# 16                                                   []
# 17                                                  [9]
# 18                                                  [1]
# 19                                       [5, 14, 10, 2]
# 20                                                  [5]
# 21                                               [9, 1]
# 22                                               [9, 1]
# 23                                                  [6]
# 24                                       [14, 6, 2, 10]
# 25                                              [14, 1]
# 26                                              [6, 14]
# 27                                              [14, 2]
# 28                                                   []
# 29                                                  [6]
# ...                                                 ...
# 1506                                                 []
# 1507                                                 []
# 1508                                                 []
# 1509                                                 []
# 1510                                                 []
# 1511                                                 []
# 1512                                                 []
# 1513                                                 []
# 1514                                                 []
# 1515                                                 []
# 1516                                                 []
# 1517                                                 []
# 1518                                                 []
# 1519                                                 []
# 1520  [9, 10, 5, 1, 13, 2, 6, 7, 8, 15, 14, 16, 4, 3...
# 1521                                             [9, 5]
# 1522                                          [5, 6, 7]
# 1523                             [9, 1, 5, 13, 2, 3, 4]
# 1524                     [9, 10, 12, 5, 1, 13, 2, 3, 4]
# 1525                 [9, 10, 12, 11, 13, 1, 5, 6, 7, 8]
# 1526                 [5, 9, 13, 1, 6, 7, 14, 16, 15, 8]
# 1527                 [9, 5, 1, 13, 2, 3, 4, 14, 16, 15]
# 1528                                  [9, 13, 1, 5, 10]
# 1529                                 [9, 5, 10, 12, 11]
# 1530                                     [5, 9, 10, 12]
# 1531                                                [9]
# 1532                                          [9, 1, 5]
# 1533                                      [9, 5, 1, 13]
# 1534                                      [9, 5, 1, 13]
# 1535                                      [9, 1, 5, 13]
#
#                                             click_times             path  \
# 0     [2692, 3813, 4808, 7601, 13713, 15045, 15845, ...     [1, 5, 6, 7]
# 1                                          [3801, 5825]   [1, 9, 10, 12]
# 2                                          [2081, 3815]     [1, 5, 6, 8]
# 3                              [1609, 2946, 4339, 5745]     [1, 5, 6, 7]
# 4                                                [3112]     [1, 5, 6, 7]
# 5                                                    []     [1, 5, 6, 8]
# 6                                                    []   [1, 9, 10, 12]
# 7                                                    []     [1, 1, 2, 4]
# 8                                                    []     [1, 5, 6, 7]
# 9                             [7675, 8558, 9695, 10726]   [1, 9, 10, 12]
# 10    [4161, 5847, 6725, 7624, 9149, 10183, 11338, 1...     [1, 1, 2, 3]
# 11                                               [2442]   [1, 9, 10, 12]
# 12                                                   []     [1, 5, 6, 7]
# 13                                                   []   [1, 9, 10, 12]
# 14                                               [2361]   [1, 9, 10, 12]
# 15                                         [2091, 4038]     [1, 5, 6, 8]
# 16                                                   []     [1, 1, 2, 3]
# 17                                               [2341]   [1, 9, 10, 12]
# 18                                               [5583]     [1, 1, 2, 4]
# 19                            [2547, 6400, 8835, 11486]  [1, 13, 14, 16]
# 20                                               [2270]     [1, 5, 6, 8]
# 21                                         [1793, 3594]  [1, 13, 14, 15]
# 22                                         [1834, 4756]   [1, 9, 10, 12]
# 23                                               [3520]     [1, 5, 6, 7]
# 24                              [842, 2724, 4003, 6189]  [1, 13, 14, 16]
# 25                                         [2088, 3656]     [1, 1, 2, 3]
# 26                                         [3204, 5254]  [1, 13, 14, 15]
# 27                                         [3313, 4943]   [1, 9, 10, 12]
# 28                                                   []  [1, 13, 14, 16]
# 29                                               [2066]  [1, 13, 14, 15]
# ...                                                 ...              ...
# 1506                                                 []  [1, 13, 14, 16]
# 1507                                                 []     [1, 5, 6, 7]
# 1508                                                 []     [1, 1, 2, 3]
# 1509                                                 []  [1, 13, 14, 15]
# 1510                                                 []   [1, 9, 10, 12]
# 1511                                                 []     [1, 5, 6, 7]
# 1512                                                 []   [1, 9, 10, 12]
# 1513                                                 []  [1, 13, 14, 16]
# 1514                                                 []     [1, 1, 2, 3]
# 1515                                                 []     [1, 5, 6, 8]
# 1516                                                 []     [1, 1, 2, 4]
# 1517                                                 []  [1, 13, 14, 15]
# 1518                                                 []  [1, 13, 14, 16]
# 1519                                                 []   [1, 9, 10, 11]
# 1520  [3549, 5619, 7887, 9060, 9904, 12679, 15395, 1...   [1, 9, 10, 12]
# 1521                                       [2810, 4446]     [1, 5, 6, 7]
# 1522                                 [3952, 6322, 7197]     [1, 5, 6, 7]
# 1523          [980, 2114, 3200, 4045, 4944, 5694, 6522]     [1, 1, 2, 4]
# 1524  [817, 2309, 3051, 5897, 7072, 8392, 9425, 1005...   [1, 9, 10, 12]
# 1525  [1604, 4112, 4910, 5958, 7381, 8146, 8818, 947...     [1, 5, 6, 8]
# 1526  [1131, 2358, 3197, 3887, 5020, 5912, 7385, 804...     [1, 5, 6, 7]
# 1527  [702, 1327, 1967, 2530, 3545, 4139, 4916, 5757...  [1, 13, 14, 16]
# 1528                      [894, 1613, 2175, 2683, 4137]   [1, 9, 10, 11]
# 1529                      [762, 1395, 2989, 3559, 4309]   [1, 9, 10, 11]
# 1530                           [5596, 6190, 7370, 7956]   [1, 9, 10, 12]
# 1531                                              [727]   [1, 9, 10, 11]
# 1532                                  [742, 1506, 2492]     [1, 1, 2, 3]
# 1533                           [1011, 1903, 2615, 3115]     [1, 5, 6, 8]
# 1534                            [796, 1368, 1984, 2476]   [1, 9, 10, 12]
# 1535                           [3032, 3678, 4436, 4990]  [1, 13, 14, 16]
#
#                action_times
# 0     [71892, 77817, 81863]
# 1      [7534, 21008, 22827]
# 2      [5649, 14086, 16738]
# 3      [8788, 15820, 17077]
# 4       [5477, 9516, 14710]
# 5       [3077, 7200, 10754]
# 6        [2198, 6520, 8274]
# 7        [3118, 6943, 8352]
# 8        [2954, 6727, 8846]
# 9     [12048, 25717, 27326]
# 10    [15977, 16992, 17881]
# 11      [3828, 8826, 10006]
# 12       [1411, 2960, 4159]
# 13       [2085, 4279, 5691]
# 14     [5478, 10990, 12063]
# 15     [5700, 12812, 13802]
# 16      [5201, 9632, 15394]
# 17     [4048, 25349, 28004]
# 18      [7592, 9750, 11712]
# 19    [14408, 16307, 18605]
# 20       [3511, 4924, 6106]
# 21       [5812, 7466, 9151]
# 22       [6296, 7439, 8755]
# 23       [4689, 6669, 7930]
# 24      [7633, 9181, 10044]
# 25       [4601, 6144, 7528]
# 26       [6396, 8089, 9101]
# 27      [6524, 9133, 10475]
# 28       [2489, 3921, 5433]
# 29       [4507, 6343, 7705]
# ...                     ...
# 1506      [792, 4743, 6358]
# 1507      [691, 3545, 5363]
# 1508      [480, 2130, 3402]
# 1509     [1932, 2987, 3846]
# 1510      [393, 2152, 3440]
# 1511     [1435, 2428, 3667]
# 1512     [2195, 3451, 4593]
# 1513      [405, 1307, 2738]
# 1514     [3470, 4550, 5640]
# 1515     [1206, 2203, 3175]
# 1516      [397, 1365, 2791]
# 1517     [2471, 3488, 4448]
# 1518      [820, 2752, 4020]
# 1519      [485, 1573, 2632]
# 1520  [25433, 30212, 31709]
# 1521   [6885, 24132, 27015]
# 1522   [9593, 13646, 15035]
# 1523   [8231, 12366, 15485]
# 1524  [11745, 15968, 20317]
# 1525  [12733, 16748, 18344]
# 1526  [12861, 16860, 18952]
# 1527   [8942, 12876, 14366]
# 1528   [6679, 10725, 12160]
# 1529   [6910, 10837, 12000]
# 1530   [9675, 11062, 12144]
# 1531     [3258, 5308, 6911]
# 1532     [3893, 5225, 6995]
# 1533     [4548, 5600, 7084]
# 1534     [5076, 6092, 7119]
# 1535     [6144, 7108, 8009]
#
# [1536 rows x 14 columns]

# %%
def make_env(depth, reward, cost, ground_truth=False):
    """Returns a MouselabEnv with given depth and cost. 
    If `ground_truth` is True, the reward observed at a given node will be
    constant across runs on this env. This reduces variance of the return."""
    env = MouselabEnv(depth, reward=reward, cost=cost)
    if ground_truth:
        env.ground_truth = np.array([0, *reward.sample(len(env.tree) - 1)])
    return env

def make_envs(depth, reward, cost, n=100, ground_truth=None):
    # Note, ground_truth can be an int in which case it acts as a random seed.
    if ground_truth is not None:
        np.random.seed(ground_truth)
        return [make_env(depth, reward, cost, True) for _ in range(n)]
    else:
        return [make_env(depth, reward, cost, False)] * n

# %%
with open('../experiments/exp1/static/json/q_weights.json') as data_file:    
    q_weights = json.load(data_file)
pprint(q_weights)
# Out:
# {'0.25': [2.257763937377627,
#           0.10443792456696127,
#           0.05249963763298343,
#           0.8577953703345867,
#           0.9978041373296709],
#  '1.00': [2.978177180936807,
#           0.3624859344787723,
#           0.19189036343344185,
#           0.5238392058288387,
#           1.000876097233912],
#  '4.00': [0.9827822354989232,
#           1.005266776096542,
#           -0.0016595283956967466,
#           -0.0027069522504898046,
#           1.0003765120051233]}

# %%
trials['pr_sum'] = np.zeros(trials.shape[0])

# %%
dist = Normal(0,10)
reward = dist.to_discrete(6)
costs = [0.25,1.00,4.00]
stimuli_envs ={str(cost):make_envs([4,1,2], reward, cost, n=16, ground_truth=1) for cost in costs}
stimuli_envs
# Out:
# {'0.25': [<mouselab.MouselabEnv at 0x1256715c0>,
#   <mouselab.MouselabEnv at 0x126bb62e8>,
#   <mouselab.MouselabEnv at 0x126bca9e8>,
#   <mouselab.MouselabEnv at 0x12568e860>,
#   <mouselab.MouselabEnv at 0x1256717b8>,
#   <mouselab.MouselabEnv at 0x126b0c7b8>,
#   <mouselab.MouselabEnv at 0x125693470>,
#   <mouselab.MouselabEnv at 0x12569ba90>,
#   <mouselab.MouselabEnv at 0x126b58ac8>,
#   <mouselab.MouselabEnv at 0x126bde320>,
#   <mouselab.MouselabEnv at 0x126bdeb38>,
#   <mouselab.MouselabEnv at 0x126be75f8>,
#   <mouselab.MouselabEnv at 0x1256a8e10>,
#   <mouselab.MouselabEnv at 0x114770080>,
#   <mouselab.MouselabEnv at 0x126b2be80>,
#   <mouselab.MouselabEnv at 0x1256fd2b0>],
#  '1.0': [<mouselab.MouselabEnv at 0x1256fd550>,
#   <mouselab.MouselabEnv at 0x1256fd1d0>,
#   <mouselab.MouselabEnv at 0x1256fd828>,
#   <mouselab.MouselabEnv at 0x1256fd668>,
#   <mouselab.MouselabEnv at 0x1256fd978>,
#   <mouselab.MouselabEnv at 0x126c0c400>,
#   <mouselab.MouselabEnv at 0x126c0c518>,
#   <mouselab.MouselabEnv at 0x126c0cb70>,
#   <mouselab.MouselabEnv at 0x126c0ccc0>,
#   <mouselab.MouselabEnv at 0x126c0cf28>,
#   <mouselab.MouselabEnv at 0x126c201d0>,
#   <mouselab.MouselabEnv at 0x126c20438>,
#   <mouselab.MouselabEnv at 0x126c206a0>,
#   <mouselab.MouselabEnv at 0x126c20908>,
#   <mouselab.MouselabEnv at 0x126c20b70>,
#   <mouselab.MouselabEnv at 0x126c20dd8>],
#  '4.0': [<mouselab.MouselabEnv at 0x126c250b8>,
#   <mouselab.MouselabEnv at 0x126c25320>,
#   <mouselab.MouselabEnv at 0x126c25588>,
#   <mouselab.MouselabEnv at 0x126c257f0>,
#   <mouselab.MouselabEnv at 0x126c25a58>,
#   <mouselab.MouselabEnv at 0x126c25cc0>,
#   <mouselab.MouselabEnv at 0x126c25f28>,
#   <mouselab.MouselabEnv at 0x126c2c1d0>,
#   <mouselab.MouselabEnv at 0x126c2c438>,
#   <mouselab.MouselabEnv at 0x126c2c6a0>,
#   <mouselab.MouselabEnv at 0x126c2c908>,
#   <mouselab.MouselabEnv at 0x126c2cb70>,
#   <mouselab.MouselabEnv at 0x126c2cdd8>,
#   <mouselab.MouselabEnv at 0x126c35080>,
#   <mouselab.MouselabEnv at 0x126c352e8>,
#   <mouselab.MouselabEnv at 0x126c35550>]}

# %%
for index, row in trials.iterrows():
    if index % 20 == 0: print(index)
    cost = row['info_cost']
    s_cost = str(cost)
    trial_id = row['trial_index']
    
#     stimuli_envs = make_envs([4,1,2], reward, cost, n=16, ground_truth=1)
#     menv = stimuli_envs[trial_id-1]
    menv = stimuli_envs[s_cost][trial_id-1]
       
    if s_cost == '1.0': s_cost = '1.00'
    elif s_cost == '4.0': s_cost = '4.00'
    q_weight = q_weights[s_cost]
    
    clicks = ast.literal_eval(row['clicks'])
    clicks.append(17)
    pr_sum = 0
    for a in clicks:
        f = menv.action_features(a)
        pr = np.inner(q_weight,f) - np.max([np.inner(q_weight,menv.action_features(a2)) for a2 in menv.actions(menv._state)])
        menv.step(a)
        pr_sum += pr
    trials.set_value(index,'pr_sum',pr_sum)
    menv.reset()
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520

# %%
csv_ready = trials[['pid','info_cost','trial_index','pr_sum']]

# %%
csv_ready
# Out:
#       pid  info_cost  trial_index     pr_sum
# 0       0       1.00            1 -18.339020
# 1       0       1.00            2  -9.742874
# 2       0       1.00            3  -5.019801
# 3       0       1.00            4  -5.653332
# 4       0       1.00            5  -6.346801
# 5       0       1.00            6 -11.961760
# 6       0       1.00            7 -11.961760
# 7       0       1.00            8 -11.961760
# 8       0       1.00            9 -11.961760
# 9       0       1.00           10  -9.395966
# 10      0       1.00           11 -14.308702
# 11      0       1.00           12 -11.143984
# 12      0       1.00           13 -11.961760
# 13      0       1.00           14 -11.961760
# 14      0       1.00           15  -8.812100
# 15      0       1.00           16 -11.671118
# 16      1       0.25            1 -19.336993
# 17      1       0.25            2 -11.527972
# 18      1       0.25            3  -8.459202
# 19      1       0.25            4 -11.667136
# 20      1       0.25            5 -11.527972
# 21      1       0.25            6 -11.690954
# 22      1       0.25            7 -14.080751
# 23      1       0.25            8 -11.527972
# 24      1       0.25            9 -12.996477
# 25      1       0.25           10 -13.819241
# 26      1       0.25           11 -15.251086
# 27      1       0.25           12 -10.979234
# 28      1       0.25           13 -19.336993
# 29      1       0.25           14 -17.249983
# ...   ...        ...          ...        ...
# 1506  104       4.00            3  -0.150277
# 1507  104       4.00            4  -0.150277
# 1508  104       4.00            5  -0.150277
# 1509  104       4.00            6  -0.150277
# 1510  104       4.00            7  -0.150277
# 1511  104       4.00            8  -0.150277
# 1512  104       4.00            9  -0.150277
# 1513  104       4.00           10  -0.150277
# 1514  104       4.00           11  -0.150277
# 1515  104       4.00           12  -0.150277
# 1516  104       4.00           13  -0.150277
# 1517  104       4.00           14  -0.150277
# 1518  104       4.00           15  -0.150277
# 1519  104       4.00           16  -0.150277
# 1520  105       1.00            1 -12.290397
# 1521  105       1.00            2  -9.742874
# 1522  105       1.00            3  -2.104324
# 1523  105       1.00            4 -10.959891
# 1524  105       1.00            5 -22.836806
# 1525  105       1.00            6 -15.403143
# 1526  105       1.00            7 -20.779149
# 1527  105       1.00            8  -5.086352
# 1528  105       1.00            9 -11.336236
# 1529  105       1.00           10 -12.904753
# 1530  105       1.00           11  -0.395334
# 1531  105       1.00           12 -11.143984
# 1532  105       1.00           13  -7.865387
# 1533  105       1.00           14  -4.432791
# 1534  105       1.00           15 -12.985805
# 1535  105       1.00           16  -9.958634
#
# [1536 rows x 4 columns]

# %%
csv_ready.to_csv('pilot_prs.csv')
