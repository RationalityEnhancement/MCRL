# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
from agents import Agent
from mouselab import MouselabEnv
from distributions import Normal, Categorical
from policies import FixedPlanPolicy, LiederPolicy
from evaluation import *
from pprint import pprint
import ast
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
trials = pd.read_csv('../experiments/data/human/0.991/trials.csv')

# %%
trials
# Out:
#       Unnamed: 0  pid  info_cost PR_type message  trial_index  trial_i  \
# 0              0    0       1.00    none    none            1      NaN
# 1              1    0       1.00    none    none            2      NaN
# 2              2    0       1.00    none    none            3      NaN
# 3              3    0       1.00    none    none            4      NaN
# 4              4    0       1.00    none    none            5      NaN
# 5              5    0       1.00    none    none            6      NaN
# 6              6    0       1.00    none    none            7      NaN
# 7              7    0       1.00    none    none            8      NaN
# 8              8    0       1.00    none    none            9      NaN
# 9              9    0       1.00    none    none           10      NaN
# 10            10    0       1.00    none    none           11      NaN
# 11            11    0       1.00    none    none           12      NaN
# 12            12    0       1.00    none    none           13      NaN
# 13            13    0       1.00    none    none           14      NaN
# 14            14    0       1.00    none    none           15      NaN
# 15            15    0       1.00    none    none           16      NaN
# 16            16    1       0.25    none    none            1      NaN
# 17            17    1       0.25    none    none            2      NaN
# 18            18    1       0.25    none    none            3      NaN
# 19            19    1       0.25    none    none            4      NaN
# 20            20    1       0.25    none    none            5      NaN
# 21            21    1       0.25    none    none            6      NaN
# 22            22    1       0.25    none    none            7      NaN
# 23            23    1       0.25    none    none            8      NaN
# 24            24    1       0.25    none    none            9      NaN
# 25            25    1       0.25    none    none           10      NaN
# 26            26    1       0.25    none    none           11      NaN
# 27            27    1       0.25    none    none           12      NaN
# 28            28    1       0.25    none    none           13      NaN
# 29            29    1       0.25    none    none           14      NaN
# ...          ...  ...        ...     ...     ...          ...      ...
# 1506        1547  104       4.00    none    none            3      NaN
# 1507        1548  104       4.00    none    none            4      NaN
# 1508        1549  104       4.00    none    none            5      NaN
# 1509        1550  104       4.00    none    none            6      NaN
# 1510        1551  104       4.00    none    none            7      NaN
# 1511        1552  104       4.00    none    none            8      NaN
# 1512        1553  104       4.00    none    none            9      NaN
# 1513        1554  104       4.00    none    none           10      NaN
# 1514        1555  104       4.00    none    none           11      NaN
# 1515        1556  104       4.00    none    none           12      NaN
# 1516        1557  104       4.00    none    none           13      NaN
# 1517        1558  104       4.00    none    none           14      NaN
# 1518        1559  104       4.00    none    none           15      NaN
# 1519        1560  104       4.00    none    none           16      NaN
# 1520        1561  105       1.00    none    none            1      NaN
# 1521        1562  105       1.00    none    none            2      NaN
# 1522        1563  105       1.00    none    none            3      NaN
# 1523        1564  105       1.00    none    none            4      NaN
# 1524        1565  105       1.00    none    none            5      NaN
# 1525        1566  105       1.00    none    none            6      NaN
# 1526        1567  105       1.00    none    none            7      NaN
# 1527        1568  105       1.00    none    none            8      NaN
# 1528        1569  105       1.00    none    none            9      NaN
# 1529        1570  105       1.00    none    none           10      NaN
# 1530        1571  105       1.00    none    none           11      NaN
# 1531        1572  105       1.00    none    none           12      NaN
# 1532        1573  105       1.00    none    none           13      NaN
# 1533        1574  105       1.00    none    none           14      NaN
# 1534        1575  105       1.00    none    none           15      NaN
# 1535        1576  105       1.00    none    none           16      NaN
#
#       delays  score  n_click  \
# 0        [3]  12.00       16
# 1        [3]  26.00        2
# 2        [3]  26.00        2
# 3        [3]  -8.00        4
# 4        [3]  19.00        1
# 5        [3]   4.00        0
# 6        [3]  28.00        0
# 7        [3]  -4.00        0
# 8        [3]   4.00        0
# 9        [3]  -8.00        4
# 10        []  11.00        9
# 11        []  11.00        1
# 12        [] -44.00        0
# 13        []   4.00        0
# 14        []  35.00        1
# 15        []   2.00        2
# 16    [None] -12.00        0
# 17    [None]  27.75        1
# 18    [None]  19.75        1
# 19    [None]  -5.00        4
# 20    [None]  27.75        1
# 21    [None] -20.50        2
# 22    [None]  27.50        2
# 23    [None]  27.75        1
# 24    [None] -21.00        4
# 25    [None]  19.50        2
# 26        []  11.50        2
# 27        []  35.50        2
# 28        []  28.00        0
# 29        []  11.75        1
# ...      ...    ...      ...
# 1506  [None]  -4.00        0
# 1507  [None]  -4.00        0
# 1508  [None] -36.00        0
# 1509  [None]  -4.00        0
# 1510  [None]  28.00        0
# 1511  [None] -28.00        0
# 1512  [None]  12.00        0
# 1513  [None]  28.00        0
# 1514      [] -12.00        0
# 1515      [] -28.00        0
# 1516      [] -12.00        0
# 1517      [] -20.00        0
# 1518      []  -4.00        0
# 1519      []  -4.00        0
# 1520     [3] -20.00       16
# 1521     [3]  18.00        2
# 1522     [3]  -7.00        3
# 1523     [3]  37.00        7
# 1524     [3]  19.00        9
# 1525     [3]  26.00       10
# 1526     [3]  18.00       10
# 1527     [3]  18.00       10
# 1528     [3]  -9.00        5
# 1529     [3]  15.00        5
# 1530      []  32.00        4
# 1531      []  35.00        1
# 1532      []  17.00        3
# 1533      []   0.00        4
# 1534      []  -8.00        4
# 1535      []   0.00        4
#
#                                                  clicks  \
# 0     [5, 6, 7, 8, 9, 10, 12, 11, 1, 2, 3, 4, 13, 14...
# 1                                                [5, 9]
# 2                                                [5, 6]
# 3                                         [5, 13, 9, 1]
# 4                                                   [5]
# 5                                                    []
# 6                                                    []
# 7                                                    []
# 8                                                    []
# 9                                         [5, 9, 13, 1]
# 10                     [9, 10, 12, 11, 13, 5, 6, 14, 2]
# 11                                                  [9]
# 12                                                   []
# 13                                                   []
# 14                                                 [12]
# 15                                               [7, 8]
# 16                                                   []
# 17                                                  [9]
# 18                                                  [1]
# 19                                       [5, 14, 10, 2]
# 20                                                  [5]
# 21                                               [9, 1]
# 22                                               [9, 1]
# 23                                                  [6]
# 24                                       [14, 6, 2, 10]
# 25                                              [14, 1]
# 26                                              [6, 14]
# 27                                              [14, 2]
# 28                                                   []
# 29                                                  [6]
# ...                                                 ...
# 1506                                                 []
# 1507                                                 []
# 1508                                                 []
# 1509                                                 []
# 1510                                                 []
# 1511                                                 []
# 1512                                                 []
# 1513                                                 []
# 1514                                                 []
# 1515                                                 []
# 1516                                                 []
# 1517                                                 []
# 1518                                                 []
# 1519                                                 []
# 1520  [9, 10, 5, 1, 13, 2, 6, 7, 8, 15, 14, 16, 4, 3...
# 1521                                             [9, 5]
# 1522                                          [5, 6, 7]
# 1523                             [9, 1, 5, 13, 2, 3, 4]
# 1524                     [9, 10, 12, 5, 1, 13, 2, 3, 4]
# 1525                 [9, 10, 12, 11, 13, 1, 5, 6, 7, 8]
# 1526                 [5, 9, 13, 1, 6, 7, 14, 16, 15, 8]
# 1527                 [9, 5, 1, 13, 2, 3, 4, 14, 16, 15]
# 1528                                  [9, 13, 1, 5, 10]
# 1529                                 [9, 5, 10, 12, 11]
# 1530                                     [5, 9, 10, 12]
# 1531                                                [9]
# 1532                                          [9, 1, 5]
# 1533                                      [9, 5, 1, 13]
# 1534                                      [9, 5, 1, 13]
# 1535                                      [9, 1, 5, 13]
#
#                                             click_times             path  \
# 0     [2692, 3813, 4808, 7601, 13713, 15045, 15845, ...     [1, 5, 6, 7]
# 1                                          [3801, 5825]   [1, 9, 10, 12]
# 2                                          [2081, 3815]     [1, 5, 6, 8]
# 3                              [1609, 2946, 4339, 5745]     [1, 5, 6, 7]
# 4                                                [3112]     [1, 5, 6, 7]
# 5                                                    []     [1, 5, 6, 8]
# 6                                                    []   [1, 9, 10, 12]
# 7                                                    []     [1, 1, 2, 4]
# 8                                                    []     [1, 5, 6, 7]
# 9                             [7675, 8558, 9695, 10726]   [1, 9, 10, 12]
# 10    [4161, 5847, 6725, 7624, 9149, 10183, 11338, 1...     [1, 1, 2, 3]
# 11                                               [2442]   [1, 9, 10, 12]
# 12                                                   []     [1, 5, 6, 7]
# 13                                                   []   [1, 9, 10, 12]
# 14                                               [2361]   [1, 9, 10, 12]
# 15                                         [2091, 4038]     [1, 5, 6, 8]
# 16                                                   []     [1, 1, 2, 3]
# 17                                               [2341]   [1, 9, 10, 12]
# 18                                               [5583]     [1, 1, 2, 4]
# 19                            [2547, 6400, 8835, 11486]  [1, 13, 14, 16]
# 20                                               [2270]     [1, 5, 6, 8]
# 21                                         [1793, 3594]  [1, 13, 14, 15]
# 22                                         [1834, 4756]   [1, 9, 10, 12]
# 23                                               [3520]     [1, 5, 6, 7]
# 24                              [842, 2724, 4003, 6189]  [1, 13, 14, 16]
# 25                                         [2088, 3656]     [1, 1, 2, 3]
# 26                                         [3204, 5254]  [1, 13, 14, 15]
# 27                                         [3313, 4943]   [1, 9, 10, 12]
# 28                                                   []  [1, 13, 14, 16]
# 29                                               [2066]  [1, 13, 14, 15]
# ...                                                 ...              ...
# 1506                                                 []  [1, 13, 14, 16]
# 1507                                                 []     [1, 5, 6, 7]
# 1508                                                 []     [1, 1, 2, 3]
# 1509                                                 []  [1, 13, 14, 15]
# 1510                                                 []   [1, 9, 10, 12]
# 1511                                                 []     [1, 5, 6, 7]
# 1512                                                 []   [1, 9, 10, 12]
# 1513                                                 []  [1, 13, 14, 16]
# 1514                                                 []     [1, 1, 2, 3]
# 1515                                                 []     [1, 5, 6, 8]
# 1516                                                 []     [1, 1, 2, 4]
# 1517                                                 []  [1, 13, 14, 15]
# 1518                                                 []  [1, 13, 14, 16]
# 1519                                                 []   [1, 9, 10, 11]
# 1520  [3549, 5619, 7887, 9060, 9904, 12679, 15395, 1...   [1, 9, 10, 12]
# 1521                                       [2810, 4446]     [1, 5, 6, 7]
# 1522                                 [3952, 6322, 7197]     [1, 5, 6, 7]
# 1523          [980, 2114, 3200, 4045, 4944, 5694, 6522]     [1, 1, 2, 4]
# 1524  [817, 2309, 3051, 5897, 7072, 8392, 9425, 1005...   [1, 9, 10, 12]
# 1525  [1604, 4112, 4910, 5958, 7381, 8146, 8818, 947...     [1, 5, 6, 8]
# 1526  [1131, 2358, 3197, 3887, 5020, 5912, 7385, 804...     [1, 5, 6, 7]
# 1527  [702, 1327, 1967, 2530, 3545, 4139, 4916, 5757...  [1, 13, 14, 16]
# 1528                      [894, 1613, 2175, 2683, 4137]   [1, 9, 10, 11]
# 1529                      [762, 1395, 2989, 3559, 4309]   [1, 9, 10, 11]
# 1530                           [5596, 6190, 7370, 7956]   [1, 9, 10, 12]
# 1531                                              [727]   [1, 9, 10, 11]
# 1532                                  [742, 1506, 2492]     [1, 1, 2, 3]
# 1533                           [1011, 1903, 2615, 3115]     [1, 5, 6, 8]
# 1534                            [796, 1368, 1984, 2476]   [1, 9, 10, 12]
# 1535                           [3032, 3678, 4436, 4990]  [1, 13, 14, 16]
#
#                action_times
# 0     [71892, 77817, 81863]
# 1      [7534, 21008, 22827]
# 2      [5649, 14086, 16738]
# 3      [8788, 15820, 17077]
# 4       [5477, 9516, 14710]
# 5       [3077, 7200, 10754]
# 6        [2198, 6520, 8274]
# 7        [3118, 6943, 8352]
# 8        [2954, 6727, 8846]
# 9     [12048, 25717, 27326]
# 10    [15977, 16992, 17881]
# 11      [3828, 8826, 10006]
# 12       [1411, 2960, 4159]
# 13       [2085, 4279, 5691]
# 14     [5478, 10990, 12063]
# 15     [5700, 12812, 13802]
# 16      [5201, 9632, 15394]
# 17     [4048, 25349, 28004]
# 18      [7592, 9750, 11712]
# 19    [14408, 16307, 18605]
# 20       [3511, 4924, 6106]
# 21       [5812, 7466, 9151]
# 22       [6296, 7439, 8755]
# 23       [4689, 6669, 7930]
# 24      [7633, 9181, 10044]
# 25       [4601, 6144, 7528]
# 26       [6396, 8089, 9101]
# 27      [6524, 9133, 10475]
# 28       [2489, 3921, 5433]
# 29       [4507, 6343, 7705]
# ...                     ...
# 1506      [792, 4743, 6358]
# 1507      [691, 3545, 5363]
# 1508      [480, 2130, 3402]
# 1509     [1932, 2987, 3846]
# 1510      [393, 2152, 3440]
# 1511     [1435, 2428, 3667]
# 1512     [2195, 3451, 4593]
# 1513      [405, 1307, 2738]
# 1514     [3470, 4550, 5640]
# 1515     [1206, 2203, 3175]
# 1516      [397, 1365, 2791]
# 1517     [2471, 3488, 4448]
# 1518      [820, 2752, 4020]
# 1519      [485, 1573, 2632]
# 1520  [25433, 30212, 31709]
# 1521   [6885, 24132, 27015]
# 1522   [9593, 13646, 15035]
# 1523   [8231, 12366, 15485]
# 1524  [11745, 15968, 20317]
# 1525  [12733, 16748, 18344]
# 1526  [12861, 16860, 18952]
# 1527   [8942, 12876, 14366]
# 1528   [6679, 10725, 12160]
# 1529   [6910, 10837, 12000]
# 1530   [9675, 11062, 12144]
# 1531     [3258, 5308, 6911]
# 1532     [3893, 5225, 6995]
# 1533     [4548, 5600, 7084]
# 1534     [5076, 6092, 7119]
# 1535     [6144, 7108, 8009]
#
# [1536 rows x 14 columns]

# %%
def make_env(depth, reward, cost, ground_truth=False):
    """Returns a MouselabEnv with given depth and cost. 
    If `ground_truth` is True, the reward observed at a given node will be
    constant across runs on this env. This reduces variance of the return."""
    env = MouselabEnv(depth, reward=reward, cost=cost)
    if ground_truth:
        env.ground_truth = np.array([0, *reward.sample(len(env.tree) - 1)])
    return env

def make_envs(depth, reward, cost, n=100, ground_truth=None):
    # Note, ground_truth can be an int in which case it acts as a random seed.
    if ground_truth is not None:
        np.random.seed(ground_truth)
        return [make_env(depth, reward, cost, True) for _ in range(n)]
    else:
        return [make_env(depth, reward, cost, False)] * n

# %%
with open('../experiments/exp1/static/json/q_weights.json') as data_file:    
    q_weights = json.load(data_file)
pprint(q_weights)
# Out:
# {'0.25': [2.3252393134113225,
#           0.09975155227317743,
#           0.08032182729437333,
#           0.8450937421220647,
#           0.997435322775085],
#  '1.00': [1.9484115264310722,
#           0.4288647055137153,
#           0.269370854918958,
#           0.44258532182537325,
#           0.9912367388407017],
#  '4.00': [1.02455453397985,
#           0.9723698649146737,
#           0.0048616156760657794,
#           0.01790135732732076,
#           1.000241178138463]}

# %%
trials['pr_sum'] = np.zeros(trials.shape[0])
trials['click_prs'] = [[]]*trials.shape[0]

# %%
dist = Normal(0,10)
reward = dist.to_discrete(6)
costs = [0.25,1.00,4.00]
stimuli_envs ={str(cost):make_envs([4,1,2], reward, cost, n=16, ground_truth=1) for cost in costs}
stimuli_envs
# Out:
# {'0.25': [<mouselab.MouselabEnv at 0x2aacda66b710>,
#   <mouselab.MouselabEnv at 0x2aacda66bac8>,
#   <mouselab.MouselabEnv at 0x2aacda66bd68>,
#   <mouselab.MouselabEnv at 0x2aacda66bfd0>,
#   <mouselab.MouselabEnv at 0x2aacda67d048>,
#   <mouselab.MouselabEnv at 0x2aacda67d2b0>,
#   <mouselab.MouselabEnv at 0x2aacda67d518>,
#   <mouselab.MouselabEnv at 0x2aacda67d780>,
#   <mouselab.MouselabEnv at 0x2aacda67d9e8>,
#   <mouselab.MouselabEnv at 0x2aacda67cd30>,
#   <mouselab.MouselabEnv at 0x2aacda66b390>,
#   <mouselab.MouselabEnv at 0x2aacda6c2198>,
#   <mouselab.MouselabEnv at 0x2aacda6c2400>,
#   <mouselab.MouselabEnv at 0x2aacda6c2668>,
#   <mouselab.MouselabEnv at 0x2aacda6c28d0>,
#   <mouselab.MouselabEnv at 0x2aacda6c2b38>],
#  '1.0': [<mouselab.MouselabEnv at 0x2aacda6c2e10>,
#   <mouselab.MouselabEnv at 0x2aacda6c6198>,
#   <mouselab.MouselabEnv at 0x2aacda6c64e0>,
#   <mouselab.MouselabEnv at 0x2aacda6c6828>,
#   <mouselab.MouselabEnv at 0x2aacda6c6b70>,
#   <mouselab.MouselabEnv at 0x2aacda6c6eb8>,
#   <mouselab.MouselabEnv at 0x2aacda6ca240>,
#   <mouselab.MouselabEnv at 0x2aacda6ca588>,
#   <mouselab.MouselabEnv at 0x2aacda6ca8d0>,
#   <mouselab.MouselabEnv at 0x2aacda6cac18>,
#   <mouselab.MouselabEnv at 0x2aacda6caf60>,
#   <mouselab.MouselabEnv at 0x2aacda6cf2e8>,
#   <mouselab.MouselabEnv at 0x2aacda6cf630>,
#   <mouselab.MouselabEnv at 0x2aacda6cf978>,
#   <mouselab.MouselabEnv at 0x2aacda6cfcc0>,
#   <mouselab.MouselabEnv at 0x2aacda6d3048>],
#  '4.0': [<mouselab.MouselabEnv at 0x2aacda6d33c8>,
#   <mouselab.MouselabEnv at 0x2aacda6d3710>,
#   <mouselab.MouselabEnv at 0x2aacda5df5c0>,
#   <mouselab.MouselabEnv at 0x2aacda6d3c88>,
#   <mouselab.MouselabEnv at 0x2aacda6d3ef0>,
#   <mouselab.MouselabEnv at 0x2aacda6d5240>,
#   <mouselab.MouselabEnv at 0x2aacda6d5588>,
#   <mouselab.MouselabEnv at 0x2aacda6d58d0>,
#   <mouselab.MouselabEnv at 0x2aacda6d5c18>,
#   <mouselab.MouselabEnv at 0x2aacda6d5f60>,
#   <mouselab.MouselabEnv at 0x2aacda6da2e8>,
#   <mouselab.MouselabEnv at 0x2aacda6da630>,
#   <mouselab.MouselabEnv at 0x2aacda6da978>,
#   <mouselab.MouselabEnv at 0x2aacda6dacc0>,
#   <mouselab.MouselabEnv at 0x2aacda6df048>,
#   <mouselab.MouselabEnv at 0x2aacda6df390>]}

# %%
thetas = [[2.55,0.47,0.18,0.35,1.0],[1.00,0.42,0.42,0.17,1.0],[5.74,0.32,0.00,0.68,1.0]]
optimal_reward = np.zeros((16,3))
worst_reward = np.zeros((16,3))
lc_pol_reward = np.zeros((16,3))
clicks = np.zeros((16,3))
for cost_id in range(3):
    policy = LiederPolicy(thetas[cost_id])
    envs =  stimuli_envs[str(costs[cost_id])]
    ev = evaluate(policy, envs)
    lc_pol_reward[:,cost_id] = ev['util']
    clicks[:,cost_id] = ev['observations']
    for env_id in range(16):
        env.reset()
        env = envs[env_id]
        optimal_reward[env_id,cost_id] = env.true_Q(0)
        worst_reward[env_id,cost_id] = env.worst_Q(0)
        env.reset()

# %%
optimal_reward
# Out:
# array([[  4.,   4.,   4.],
#        [ 36.,  36.,  36.],
#        [ 36.,  36.,  36.],
#        [ -4.,  -4.,  -4.],
#        [ 28.,  28.,  28.],
#        [ 28.,  28.,  28.],
#        [ 28.,  28.,  28.],
#        [ 28.,  28.,  28.],
#        [ 20.,  20.,  20.],
#        [ 12.,  12.,  12.],
#        [ 28.,  28.,  28.],
#        [ 12.,  12.,  12.],
#        [ 36.,  36.,  36.],
#        [ 44.,  44.,  44.],
#        [ 28.,  28.,  28.],
#        [ 36.,  36.,  36.]])

# %%
worst_reward
# Out:
# array([[-36., -36., -36.],
#        [-12., -12., -12.],
#        [-20., -20., -20.],
#        [-36., -36., -36.],
#        [-12., -12., -12.],
#        [ -4.,  -4.,  -4.],
#        [ -4.,  -4.,  -4.],
#        [-60., -60., -60.],
#        [-20., -20., -20.],
#        [-36., -36., -36.],
#        [-44., -44., -44.],
#        [-20., -20., -20.],
#        [-20., -20., -20.],
#        [-36., -36., -36.],
#        [-20., -20., -20.],
#        [-12., -12., -12.]])

# %%
lc_pol_reward
# Out:
# array([[  1.000e+00,  -8.000e+00,  -4.441e-16],
#        [  3.400e+01,   2.800e+01,  -4.441e-16],
#        [  3.375e+01,   2.700e+01,  -4.441e-16],
#        [  5.750e+00,   1.000e+00,  -4.441e-16],
#        [  2.575e+01,   2.000e+01,  -4.441e-16],
#        [  2.575e+01,   1.100e+01,  -4.441e-16],
#        [  2.575e+01,   1.900e+01,  -4.441e-16],
#        [  2.475e+01,   1.100e+01,  -4.441e-16],
#        [  1.750e+01,   1.300e+01,  -4.441e-16],
#        [  9.250e+00,   1.000e+00,  -4.441e-16],
#        [  2.600e+01,   2.000e+01,  -4.441e-16],
#        [  8.750e+00,   2.000e+00,  -4.441e-16],
#        [  3.400e+01,   2.700e+01,  -4.441e-16],
#        [  3.100e+01,   2.900e+01,  -4.441e-16],
#        [  2.625e+01,   1.800e+01,  -4.441e-16],
#        [  3.350e+01,   7.000e+00,  -4.441e-16]])

# %%
rel = (lc_pol_reward-worst_reward)/(optimal_reward-worst_reward)
rel
# Out:
# array([[ 0.925,  0.7  ,  0.9  ],
#        [ 0.958,  0.833,  0.25 ],
#        [ 0.96 ,  0.839,  0.357],
#        [ 1.305,  1.156,  1.125],
#        [ 0.944,  0.8  ,  0.3  ],
#        [ 0.93 ,  0.469,  0.125],
#        [ 0.93 ,  0.719,  0.125],
#        [ 0.963,  0.807,  0.682],
#        [ 0.938,  0.825,  0.5  ],
#        [ 0.943,  0.771,  0.75 ],
#        [ 0.972,  0.889,  0.611],
#        [ 0.898,  0.688,  0.625],
#        [ 0.964,  0.839,  0.357],
#        [ 0.838,  0.812,  0.45 ],
#        [ 0.964,  0.792,  0.417],
#        [ 0.948,  0.396,  0.25 ]])

# %%
clicks
# Out:
# array([[ 12.,  12.,   0.],
#        [  8.,   8.,   0.],
#        [  9.,   9.,   0.],
#        [  9.,   7.,   0.],
#        [  9.,   4.,   0.],
#        [  9.,   9.,   0.],
#        [  9.,   9.,   0.],
#        [ 13.,   9.,   0.],
#        [ 10.,   7.,   0.],
#        [ 11.,  11.,   0.],
#        [  8.,   8.,   0.],
#        [ 13.,  10.,   0.],
#        [  8.,   5.,   0.],
#        [  4.,   3.,   0.],
#        [  7.,  10.,   0.],
#        [ 10.,   9.,   0.]])

# %%
np.savetxt('../experiments/data/stimuli/exp1/optimal1A.2.csv', optimal_reward, delimiter=",")
np.savetxt('../experiments/data/stimuli/exp1/worst1A.2.csv', worst_reward, delimiter=",")
np.savetxt('../experiments/data/stimuli/exp1/rel_score_pi_star1A.2.csv', rel, delimiter=",")
np.savetxt('../experiments/data/stimuli/exp1/nr_observations_pi_star1A.2.csv', clicks, delimiter=",")

# %%
for index, row in trials.iterrows():
    if index % 20 == 0: print(index)
    cost = row['info_cost']
    s_cost = str(cost)
    trial_id = row['trial_index']
    
#     stimuli_envs = make_envs([4,1,2], reward, cost, n=16, ground_truth=1)
#     menv = stimuli_envs[trial_id-1]
    menv = stimuli_envs[s_cost][trial_id-1]
       
    if s_cost == '1.0': s_cost = '1.00'
    elif s_cost == '4.0': s_cost = '4.00'
    q_weight = q_weights[s_cost]
    
    clicks = ast.literal_eval(row['clicks'])
    clicks.append(17)
    pr_sum = 0
    click_prs = []
    for a in clicks:
        f = menv.action_features(a)
        pr = np.inner(q_weight,f) - np.max([np.inner(q_weight,menv.action_features(a2)) for a2 in menv.actions(menv._state)])
        menv.step(a)
        pr_sum += pr
        click_prs.append(pr)
    trials.set_value(index,'pr_sum',pr_sum)
    trials.set_value(index,'click_prs',click_prs)
    menv.reset()
# Out:
# 0
# 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-eba3c9b82484> in <module>()
#      18     click_prs = []
#      19     for a in clicks:
# ---> 20         f = menv.action_features(a)
#      21         pr = np.inner(q_weight,f) - np.max([np.inner(q_weight,menv.action_features(a2)) for a2 in menv.actions(menv._state)])
#      22         menv.step(a)
#
# /global/home/users/sayangul/MCRL/python/mouselab.py in action_features(self, action, state)
#     163             self.myopic_voc(action, state),
#     164             self.vpi_action(action, state),
# --> 165             self.vpi(state),
#     166             self.expected_term_reward(state)
#     167         ])
#
# /global/home/users/sayangul/MCRL/python/mouselab.py in vpi(self, state)
#     238     def vpi(self, state):
#     239         obs = self.subtree[0]
# --> 240         return (self.node_value_after_observe(obs, 0, state).expectation()
#     241                 - self.expected_term_reward(state)
#     242                 )
#
# /global/home/users/sayangul/MCRL/python/mouselab.py in node_value_after_observe(self, obs, node, state)
#     267             obs_tree = self.to_obs_tree(state, node, obs)
#     268             if self.exact:
# --> 269                 return exact_node_value_after_observe(obs_tree)
#     270             else:
#     271                 return node_value_after_observe(obs_tree)
#
# /global/home/users/sayangul/MCRL/python/mouselab.py in exact_node_value_after_observe(obs_tree)
#     436     """
#     437     children = tuple(exact_node_value_after_observe(c) + c[0] for c in obs_tree[1])
# --> 438     return cmax(children, default=ZERO)
#     439
#     440 @lru_cache(None)
#
# /global/home/users/sayangul/MCRL/python/distributions.py in cmax(dists, default)
#     322             raise ValueError('dmax() arg is an empty sequence')
#     323     else:
# --> 324         return cross(dists, max)
#     325
#     326
#
# /global/home/users/sayangul/MCRL/python/distributions.py in cross(dists, f)
#     304     for outcome_probs in it.product(*dists):
#     305         o, p = zip(*outcome_probs)
# --> 306         outcomes[f(*o)] += reduce(lambda x, y: x*y, p)
#     307
#     308     return Categorical(outcomes.keys(), outcomes.values())
#
# /global/home/users/sayangul/MCRL/python/distributions.py in <lambda>(x, y)
#     304     for outcome_probs in it.product(*dists):
#     305         o, p = zip(*outcome_probs)
# --> 306         outcomes[f(*o)] += reduce(lambda x, y: x*y, p)
#     307
#     308     return Categorical(outcomes.keys(), outcomes.values())
#
# KeyboardInterrupt:

# %%
csv_ready = trials[['pid','info_cost','trial_index','pr_sum','click_prs']]

# %%
csv_ready
# Out:
#       pid  info_cost  trial_index     pr_sum  \
# 0       0       1.00            1 -21.801828
# 1       0       1.00            2 -10.724908
# 2       0       1.00            3  -5.819986
# 3       0       1.00            4  -6.452739
# 4       0       1.00            5  -6.910454
# 5       0       1.00            6 -12.222219
# 6       0       1.00            7 -12.222219
# 7       0       1.00            8 -12.222219
# 8       0       1.00            9 -12.222219
# 9       0       1.00           10 -10.693319
# 10      0       1.00           11  -8.530718
# 11      0       1.00           12 -11.531289
# 12      0       1.00           13 -12.222219
# 13      0       1.00           14 -12.222219
# 14      0       1.00           15  -9.196463
# 15      0       1.00           16 -12.423147
# 16      1       0.25            1 -19.290150
# 17      1       0.25            2 -11.445353
# 18      1       0.25            3  -8.413949
# 19      1       0.25            4 -11.552673
# 20      1       0.25            5 -11.445353
# 21      1       0.25            6 -11.568436
# 22      1       0.25            7 -14.079975
# 23      1       0.25            8 -11.445353
# 24      1       0.25            9 -12.958081
# 25      1       0.25           10 -13.685294
# 26      1       0.25           11 -15.264744
# 27      1       0.25           12 -10.914707
# 28      1       0.25           13 -19.290150
# 29      1       0.25           14 -17.234043
# ...   ...        ...          ...        ...
# 1506  104       4.00            3  -0.363699
# 1507  104       4.00            4  -0.363699
# 1508  104       4.00            5  -0.363699
# 1509  104       4.00            6  -0.363699
# 1510  104       4.00            7  -0.363699
# 1511  104       4.00            8  -0.363699
# 1512  104       4.00            9  -0.363699
# 1513  104       4.00           10  -0.363699
# 1514  104       4.00           11  -0.363699
# 1515  104       4.00           12  -0.363699
# 1516  104       4.00           13  -0.363699
# 1517  104       4.00           14  -0.363699
# 1518  104       4.00           15  -0.363699
# 1519  104       4.00           16  -0.363699
# 1520  105       1.00            1 -14.433363
# 1521  105       1.00            2 -10.724908
# 1522  105       1.00            3  -2.714158
# 1523  105       1.00            4 -13.400003
# 1524  105       1.00            5 -28.300925
# 1525  105       1.00            6  -8.919758
# 1526  105       1.00            7 -25.485823
# 1527  105       1.00            8  -4.712430
# 1528  105       1.00            9 -12.990829
# 1529  105       1.00           10 -14.668846
# 1530  105       1.00           11  -0.394992
# 1531  105       1.00           12 -11.531289
# 1532  105       1.00           13  -9.749815
# 1533  105       1.00           14  -5.796933
# 1534  105       1.00           15 -15.355129
# 1535  105       1.00           16 -10.884975
#
#                                               click_prs
# 0     [0.0, -3.48967110132, -4.38808088052, -4.38808...
# 1                  [0.0, -1.78773376916, -8.9371740738]
# 2                [0.0, -0.394992325395, -5.42499349295]
# 3      [0.0, 0.0, 0.0, -0.432655729455, -6.02008290493]
# 4                                 [0.0, -6.91045391442]
# 5                                      [-12.2222185374]
# 6                                      [-12.2222185374]
# 7                                      [-12.2222185374]
# 8                                      [-12.2222185374]
# 9     [0.0, -0.432655729455, -1.1453229211, -1.14532...
# 10    [0.0, -0.394992325395, 0.0, -1.25301416697, -1...
# 11                                [0.0, -11.5312894479]
# 12                                     [-12.2222185374]
# 13                                     [-12.2222185374]
# 14                    [-0.380648314282, -8.81581484015]
# 15    [-0.380648314282, -0.740810834193, -11.3016880...
# 16                                     [-19.2901500703]
# 17                                [0.0, -11.4453530028]
# 18                                   [0.0, -8.41394863]
# 19    [0.0, 0.0, 0.0, -0.0943866513133, -11.4582867116]
# 20                                [0.0, -11.4453530028]
# 21                [0.0, -0.072753331083, -11.495682726]
# 22               [0.0, -0.429141020575, -13.6508335009]
# 23                                [0.0, -11.4453530028]
# 24    [0.0, 0.0, 0.0, -0.0943866513133, -12.8636944336]
# 25               [0.0, -0.072753331083, -13.6125410173]
# 26                           [0.0, 0.0, -15.2647436981]
# 27               [0.0, -0.429141020575, -10.4855662068]
# 28                                     [-19.2901500703]
# 29                                [0.0, -17.2340428613]
# ...                                                 ...
# 1506                                  [-0.363698953547]
# 1507                                  [-0.363698953547]
# 1508                                  [-0.363698953547]
# 1509                                  [-0.363698953547]
# 1510                                  [-0.363698953547]
# 1511                                  [-0.363698953547]
# 1512                                  [-0.363698953547]
# 1513                                  [-0.363698953547]
# 1514                                  [-0.363698953547]
# 1515                                  [-0.363698953547]
# 1516                                  [-0.363698953547]
# 1517                                  [-0.363698953547]
# 1518                                  [-0.363698953547]
# 1519                                  [-0.363698953547]
# 1520  [0.0, -1.83978327316, 0.0, 0.0, 0.0, -0.337675...
# 1521               [0.0, -1.78773376916, -8.9371740738]
# 1522        [0.0, -0.394992325395, 0.0, -2.31916603558]
# 1523  [0.0, -0.432655729455, -0.432655729455, -0.432...
# 1524  [0.0, -3.48967110132, -1.50210746276, 0.0, -1....
# 1525  [0.0, -0.394992325395, 0.0, -1.25301416697, -1...
# 1526  [0.0, 0.0, -1.78773376916, -1.9188827014, -3.5...
# 1527  [0.0, 0.0, -0.432655729455, -1.9188827014, 0.0...
# 1528  [0.0, -1.78773376916, -1.9188827014, -1.918882...
# 1529  [0.0, -0.432655729455, 0.0, -2.97626249053, -2...
# 1530              [0.0, 0.0, -0.394992325395, 0.0, 0.0]
# 1531                              [0.0, -11.5312894479]
# 1532  [0.0, -2.46281265184, -2.49233531595, -4.79466...
# 1533    [0.0, 0.0, 0.0, -1.78773376916, -4.00919928534]
# 1534  [0.0, -1.78773376916, -2.820733626, -2.8207336...
# 1535  [0.0, -0.432655729455, -0.432655729455, -1.145...
#
# [1536 rows x 5 columns]

# %%
res = trials.set_index(['pid','info_cost','trial_index'])['click_prs'].apply(pd.Series).stack()
res = res.reset_index()
res.columns = ['pid','info_cost','trial_index','click_num','click_pr']
res
# Out:
#       pid  info_cost  trial_index  click_num   click_pr
# 0       0        1.0            1          0   0.000000
# 1       0        1.0            1          1  -3.489671
# 2       0        1.0            1          2  -4.388081
# 3       0        1.0            1          3  -4.388081
# 4       0        1.0            1          4   0.000000
# 5       0        1.0            1          5  -1.839783
# 6       0        1.0            1          6  -1.502107
# 7       0        1.0            1          7  -1.360207
# 8       0        1.0            1          8   0.000000
# 9       0        1.0            1          9  -1.253846
# 10      0        1.0            1         10  -1.360207
# 11      0        1.0            1         11  -1.360207
# 12      0        1.0            1         12   0.000000
# 13      0        1.0            1         13  -0.859637
# 14      0        1.0            1         14   0.000000
# 15      0        1.0            1         15   0.000000
# 16      0        1.0            1         16   0.000000
# 17      0        1.0            2          0   0.000000
# 18      0        1.0            2          1  -1.787734
# 19      0        1.0            2          2  -8.937174
# 20      0        1.0            3          0   0.000000
# 21      0        1.0            3          1  -0.394992
# 22      0        1.0            3          2  -5.424993
# 23      0        1.0            4          0   0.000000
# 24      0        1.0            4          1   0.000000
# 25      0        1.0            4          2   0.000000
# 26      0        1.0            4          3  -0.432656
# 27      0        1.0            4          4  -6.020083
# 28      0        1.0            5          0   0.000000
# 29      0        1.0            5          1  -6.910454
# ...   ...        ...          ...        ...        ...
# 8576  105        1.0           10          2   0.000000
# 8577  105        1.0           10          3  -2.976262
# 8578  105        1.0           10          4  -2.976262
# 8579  105        1.0           10          5  -8.283665
# 8580  105        1.0           11          0   0.000000
# 8581  105        1.0           11          1   0.000000
# 8582  105        1.0           11          2  -0.394992
# 8583  105        1.0           11          3   0.000000
# 8584  105        1.0           11          4   0.000000
# 8585  105        1.0           12          0   0.000000
# 8586  105        1.0           12          1 -11.531289
# 8587  105        1.0           13          0   0.000000
# 8588  105        1.0           13          1  -2.462813
# 8589  105        1.0           13          2  -2.492335
# 8590  105        1.0           13          3  -4.794667
# 8591  105        1.0           14          0   0.000000
# 8592  105        1.0           14          1   0.000000
# 8593  105        1.0           14          2   0.000000
# 8594  105        1.0           14          3  -1.787734
# 8595  105        1.0           14          4  -4.009199
# 8596  105        1.0           15          0   0.000000
# 8597  105        1.0           15          1  -1.787734
# 8598  105        1.0           15          2  -2.820734
# 8599  105        1.0           15          3  -2.820734
# 8600  105        1.0           15          4  -7.925928
# 8601  105        1.0           16          0   0.000000
# 8602  105        1.0           16          1  -0.432656
# 8603  105        1.0           16          2  -0.432656
# 8604  105        1.0           16          3  -1.145323
# 8605  105        1.0           16          4  -8.874340
#
# [8606 rows x 5 columns]

# %%
csv_ready.to_csv('../experiments/data/human/0.991/pilot_prs.csv')
res.to_csv('../experiments/data/human/0.991/pilot_click_prs.csv')
